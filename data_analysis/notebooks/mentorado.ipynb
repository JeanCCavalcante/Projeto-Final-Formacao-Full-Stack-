# %% [markdown]
# Analise do dataset a troco de adiantar as metricas, graficos e insights. Quando houver a integração com mongo e etc, ja teremos meio caminho andado

# %% [markdown]
# # importacao

# %%
import pandas as pd
from canexao import connect_to_mongo
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff




collection_users, collection_tasks = connect_to_mongo()
tabela_users = pd.DataFrame(list(collection_users.find()))
tabela = pd.DataFrame(list(collection_tasks.find()))
# Out:
# Conexão estabelecida com sucesso!

# %% [markdown]
# # av. geral

# %%
tabela.info()
print(f'{tabela.shape}')

tabela.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           77 non-null     object
#  1   task_id                       76 non-null     float64
#  2   titulo                        77 non-null     str
#  3   descricao                     77 non-null     str
#  4   prioridade                    77 non-null     str
#  5   user_id                       77 non-null     object
#  6   mentorado                     77 non-null     str
#  7   area_atuacao                  76 non-null     str
#  8   mentor_responsavel            77 non-null     str
#  9   data_criacao                  76 non-null     datetime64[us]
#  10  data_inicio                   63 non-null     datetime64[us]
#  11  status_atual                  77 non-null     str
#  12  data_conclusao                44 non-null     datetime64[us]
#  13  feedback_conclusao_mentorado  44 non-null     str
#  14  createdAt                     1 non-null      datetime64[us]
#  15  updatedAt                     1 non-null      datetime64[us]
#  16  __v                           1 non-null      float64
# dtypes: datetime64[us](5), float64(2), object(2), str(8)
# memory usage: 10.4+ KB
# (77, 17)
#          task_id                data_criacao                 data_inicio  \
# count  76.000000                          76                          63
# mean   38.500000  2026-04-18 14:31:34.736842  2026-04-14 17:54:17.142857
# min     1.000000         2026-03-01 00:00:00         2026-03-03 00:00:00
# 25%    19.750000         2026-03-23 18:00:00         2026-03-23 12:00:00
# 50%    38.500000         2026-04-28 00:00:00         2026-04-16 00:00:00
# 75%    57.250000         2026-05-12 00:00:00         2026-05-08 12:00:00
# max    76.000000         2026-05-27 00:00:00         2026-06-11 00:00:00
# std    22.083176                         NaN                         NaN
#
#                    data_conclusao                   createdAt  \
# count                          44                           1
# mean   2026-04-12 08:10:54.545454  2026-06-12 04:33:03.195000
# min           2026-03-09 00:00:00  2026-06-12 04:33:03.195000
# 25%           2026-03-27 06:00:00  2026-06-12 04:33:03.195000
# 50%           2026-04-05 12:00:00  2026-06-12 04:33:03.195000
# 75%           2026-04-29 06:00:00  2026-06-12 04:33:03.195000
# max           2026-06-15 00:00:00  2026-06-12 04:33:03.195000
# std                           NaN                         NaN
#
#                         updatedAt  __v
# count                           1  1.0
# mean   2026-06-12 04:38:14.840000  0.0
# min    2026-06-12 04:38:14.840000  0.0
# 25%    2026-06-12 04:38:14.840000  0.0
# 50%    2026-06-12 04:38:14.840000  0.0
# 75%    2026-06-12 04:38:14.840000  0.0
# max    2026-06-12 04:38:14.840000  0.0
# std                           NaN  NaN

# %%
#conversao de valores para tipos adequados
tabela['task_id'] = tabela['task_id'].astype('object')
print(f"Coluna 'task_id' convertida para o tipo '{tabela['task_id'].dtype}'")
# Out:
# Coluna 'task_id' convertida para o tipo 'object'

# %%
tabela.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           77 non-null     object
#  1   task_id                       76 non-null     object
#  2   titulo                        77 non-null     str
#  3   descricao                     77 non-null     str
#  4   prioridade                    77 non-null     str
#  5   user_id                       77 non-null     object
#  6   mentorado                     77 non-null     str
#  7   area_atuacao                  76 non-null     str
#  8   mentor_responsavel            77 non-null     str
#  9   data_criacao                  76 non-null     datetime64[us]
#  10  data_inicio                   63 non-null     datetime64[us]
#  11  status_atual                  77 non-null     str
#  12  data_conclusao                44 non-null     datetime64[us]
#  13  feedback_conclusao_mentorado  44 non-null     str
#  14  createdAt                     1 non-null      datetime64[us]
#  15  updatedAt                     1 non-null      datetime64[us]
#  16  __v                           1 non-null      float64
# dtypes: datetime64[us](5), float64(1), object(3), str(8)
# memory usage: 10.4+ KB

# %%
tabela.head()
# Out:
#                         _id task_id  \
# 0  6a2b884993a2aac46c8ba14a     1.0
# 1  6a2b884993a2aac46c8ba14b     2.0
# 2  6a2b884993a2aac46c8ba14c     3.0
# 3  6a2b884993a2aac46c8ba14d     4.0
# 4  6a2b884993a2aac46c8ba14e     5.0
#
#                                         titulo  \
# 0           Otimizar Microsserviços - Sprint 8
# 1          Testar Scripts de Deploy - Sprint 2
# 2             Testar Cache em Redis - Sprint 2
# 3          Testar Componentes React - Sprint 8
# 4  Ajustar Exportação de Relatórios - Sprint 3
#
#                                            descricao prioridade  \
# 0  Atividade focada em otimizar o recurso de micr...      media
# 1  Atividade focada em testar o recurso de script...       alta
# 2  Atividade focada em testar o recurso de cache ...      media
# 3  Atividade focada em testar o recurso de compon...      media
# 4  Atividade focada em ajustar o recurso de expor...      media
#
#                     user_id       mentorado area_atuacao mentor_responsavel  \
# 0  6a2b8445cf36b576d237ae6b     Bruno Costa  DevBack-end      Juliana Costa
# 1  6a2b8468cf36b576d237ae6c  Felipe Andrade           QA      Juliana Costa
# 2  6a2b8468cf36b576d237ae6c  Felipe Andrade           QA      Juliana Costa
# 3  6a2b8496cf36b576d237ae6d   Diego Martins           QA      Juliana Costa
# 4  6a2b84b4cf36b576d237ae6e    Camila Lopes      Produto      Juliana Costa
#
#   data_criacao data_inicio status_atual data_conclusao  \
# 0   2026-05-05  2026-05-07    andamento            NaT
# 1   2026-03-25  2026-03-27    concluida     2026-04-02
# 2   2026-03-26  2026-03-27    concluida     2026-04-06
# 3   2026-04-20  2026-04-21    concluida     2026-04-27
# 4   2026-03-02  2026-03-05    concluida     2026-03-19
#
#                         feedback_conclusao_mentorado createdAt updatedAt  __v
# 0                                                NaN       NaT       NaT  NaN
# 1  Os testes cobriram os cenários críticos de aut...       NaT       NaT  NaN
# 2  Validação executada com sucesso. O fluxo corre...       NaT       NaT  NaN
# 3  Conseguimos manter uma boa cobertura de testes...       NaT       NaT  NaN
# 4  Os ajustes visuais foram concluídos no prazo. ...       NaT       NaT  NaN

# %%
tabela.drop(columns=['descricao', 'mentor_responsavel', 'createdAt','updatedAt','__v', '_id'], inplace=True, errors='ignore')

# %%
##como temos valores nulos de data de inicio e data de  conclusao q estao nulos, estamos falando de atividades que não foram concluidas/iniadas
tabela.isnull().sum()
# Out:
# task_id                          1
# titulo                           0
# prioridade                       0
# user_id                          0
# mentorado                        0
# area_atuacao                     1
# data_criacao                     1
# data_inicio                     14
# status_atual                     0
# data_conclusao                  33
# feedback_conclusao_mentorado    33
# dtype: int64

# %%
tabela.duplicated().sum()
# Out:
# np.int64(0)

# %%
tabela.head()
# Out:
#   task_id                                       titulo prioridade  \
# 0     1.0           Otimizar Microsserviços - Sprint 8      media
# 1     2.0          Testar Scripts de Deploy - Sprint 2       alta
# 2     3.0             Testar Cache em Redis - Sprint 2      media
# 3     4.0          Testar Componentes React - Sprint 8      media
# 4     5.0  Ajustar Exportação de Relatórios - Sprint 3      media
#
#                     user_id       mentorado area_atuacao data_criacao  \
# 0  6a2b8445cf36b576d237ae6b     Bruno Costa  DevBack-end   2026-05-05
# 1  6a2b8468cf36b576d237ae6c  Felipe Andrade           QA   2026-03-25
# 2  6a2b8468cf36b576d237ae6c  Felipe Andrade           QA   2026-03-26
# 3  6a2b8496cf36b576d237ae6d   Diego Martins           QA   2026-04-20
# 4  6a2b84b4cf36b576d237ae6e    Camila Lopes      Produto   2026-03-02
#
#   data_inicio status_atual data_conclusao  \
# 0  2026-05-07    andamento            NaT
# 1  2026-03-27    concluida     2026-04-02
# 2  2026-03-27    concluida     2026-04-06
# 3  2026-04-21    concluida     2026-04-27
# 4  2026-03-05    concluida     2026-03-19
#
#                         feedback_conclusao_mentorado
# 0                                                NaN
# 1  Os testes cobriram os cenários críticos de aut...
# 2  Validação executada com sucesso. O fluxo corre...
# 3  Conseguimos manter uma boa cobertura de testes...
# 4  Os ajustes visuais foram concluídos no prazo. ...

# %% [markdown]
# # analisegeral

# %%
databcorte = pd.to_datetime('2026-05-31') #é a fotografia da data, é oq nos ajuda a criar o limite pra uma data que não existe, exemplo data_inicio ou data_conclusao. Ela pode ser modificada, podemos dar outro parametro de data.

tabela['duracao_em_dias'] = np.nan #criar uma coluna vazia para receber os calculos

taskconcluida = tabela['status_atual'] == 'concluida'
tabela.loc[taskconcluida, 'duracao_em_dias'] = (tabela.loc[taskconcluida, 'data_conclusao'] - tabela.loc[taskconcluida, 'data_inicio']).dt.days  # CONCLUIDAS = DATAINICIO - DATACONCLUSAO.

# 'andamento' status
task_andamento = tabela['status_atual'] == 'andamento'
tabela.loc[task_andamento, 'duracao_em_dias'] = (databcorte - tabela.loc[task_andamento, 'data_inicio']).dt.days #DATA CORTE AGR É UMA DATA Q O SISTEMA TA DANDO COMO LIMITE PARA AS ATVD Q ESTAO EM ANDAMENTO. como se ele dissesse: Olhe, datacorte-datainicio = a qntdade de dias q ja se passaram e vc ainda ta em andamento com a atvd

# 'pendente' status
task_pendente = tabela['status_atual'] == 'pendente'
tabela.loc[task_pendente, 'duracao_em_dias'] = (databcorte - tabela.loc[task_pendente, 'data_criacao']).dt.days # ele vai pegar a datacorte - datacriacao e sinalizar: olhe, ate agora(data_corte), vc ta com essa atividade ha X dias no blocklog


#duraçao em dias para saber quantos dias aquela tarefa foi concluida ou esta em processo/pendente
concluidas = tabela[tabela['status_atual'] == 'concluida']
andamento = tabela[tabela['status_atual'] == 'andamento']
pendentes = tabela[tabela['status_atual'] == 'pendente']

# Calcular as médias isoladas (arredondadas a 1 casa decimal). O papel da média vai nos dizer: se a quantidade de dias que a atvd ta em execução/pendente é maior que a média, ai isso ja dá um alerta pra o mentor conversar procurar o mentorado e entender oq se passa
media_dia_conclusao = concluidas['duracao_em_dias'].mean().round(1)
media_dia_andamento = andamento['duracao_em_dias'].mean().round(1)
media_dia_pendente = pendentes['duracao_em_dias'].mean().round(1)


print(f'a media de dias para concluir é: {media_dia_conclusao}')
print(f'a media de dias que a atv ESTÁ EM ANDAMENTO é: {media_dia_andamento}' )
print(f'a media de dias de atv pendente é: {media_dia_pendente}')
print(concluidas)
print('===========')
print(andamento)
print('===========')
print(pendentes)
# Out:
# a media de dias para concluir é: 10.6
# a media de dias que a atv ESTÁ EM ANDAMENTO é: 16.2
# a media de dias de atv pendente é: 11.8
#    task_id                                          titulo prioridade  \
# 1      2.0             Testar Scripts de Deploy - Sprint 2       alta
# 2      3.0                Testar Cache em Redis - Sprint 2      media
# 3      4.0             Testar Componentes React - Sprint 8      media
# 4      5.0     Ajustar Exportação de Relatórios - Sprint 3      media
# 7      8.0              Criar Scripts de Deploy - Sprint 2       alta
# 9     10.0                      Criar Dashboard - Sprint 1      media
# 10    11.0             Atualizar Pipeline CI/CD - Sprint 1      media
# 11    12.0             Refatorar Microsserviços - Sprint 5      media
# 12    13.0               Refatorar API de Login - Sprint 5       alta
# 13    14.0             Documentar Tabelas no BD - Sprint 4      baixa
# 14    15.0                 Criar Pipeline CI/CD - Sprint 6       alta
# 16    17.0                      Criar Dashboard - Sprint 5      media
# 19    20.0             Refatorar Cache em Redis - Sprint 7      media
# 20    21.0             Refatorar Microsserviços - Sprint 3      media
# 21    22.0             Documentar Tabelas no BD - Sprint 6      baixa
# 22    23.0        Revisar Fluxo de Autenticação - Sprint 4       alta
# 30    31.0          Atualizar Scripts de Deploy - Sprint 6       alta
# 31    32.0               Ajustar Pipeline CI/CD - Sprint 9       alta
# 32    33.0           Analisar Componentes React - Sprint 5      baixa
# 33    34.0                 Testar Tabelas no BD - Sprint 8      media
# 35    36.0       Atualizar Gateway de Pagamento - Sprint 9      media
# 39    40.0        Ajustar Fluxo de Autenticação - Sprint 4       alta
# 41    42.0   Atualizar Exportação de Relatórios - Sprint 2      media
# 43    44.0           Analisar Componentes React - Sprint 5      baixa
# 44    45.0     Testar Exportação de Relatórios - Sprint 10      media
# 48    49.0              Testar Filtros de Busca - Sprint 8      media
# 50    51.0        Implementar Componentes React - Sprint 5       alta
# 51    52.0                Revisar API de Login - Sprint 10       alta
# 52    53.0          Refatorar Scripts de Deploy - Sprint 5       alta
# 54    55.0       Analisar Acessibilidade (WCAG) - Sprint 7      baixa
# 58    59.0                    Revisar Dashboard - Sprint 3      media
# 59    60.0         Ajustar Testes de Integração - Sprint 7       alta
# 61    62.0         Documentar Componentes React - Sprint 7      baixa
# 62    63.0        Revisar Acessibilidade (WCAG) - Sprint 4      media
# 64    65.0              Otimizar Cache em Redis - Sprint 1      media
# 65    66.0            Documentar Cache em Redis - Sprint 8      baixa
# 67    68.0         Documentar Componentes React - Sprint 4      baixa
# 69    70.0  Documentar Exportação de Relatórios - Sprint 4      baixa
# 70    71.0               Ajustar Pipeline CI/CD - Sprint 2       alta
# 71    72.0             Refatorar Pipeline CI/CD - Sprint 7      media
# 73    74.0                    Ajustar Dashboard - Sprint 6      media
# 74    75.0     Atualizar Fluxo de Autenticação - Sprint 10       alta
# 75    76.0     Atualizar Fluxo de Autenticação - Sprint 10       alta
# 76     NaN              Validar Arquitetura do TaskInsight       alta
#
#                      user_id       mentorado   area_atuacao data_criacao  \
# 1   6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-03-25
# 2   6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-03-26
# 3   6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-04-20
# 4   6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-03-02
# 7   6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-04-20
# 9   6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-27
# 10  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-03-04
# 11  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-03-10
# 12  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-08
# 13  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-04-15
# 14  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-04-21
# 16  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-31
# 19  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-03-23
# 20  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-03-26
# 21  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-03-20
# 22  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-04-21
# 30  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-08
# 31  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-03-05
# 32  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-03-24
# 33  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-03-31
# 35  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-03-10
# 39  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-03-23
# 41  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-03-01
# 43  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-03
# 44  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-03-01
# 48  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-03-31
# 50  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-13
# 51  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-03-14
# 52  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-04-24
# 54  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-04-25
# 58  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-08
# 59  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-04-09
# 61  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-10
# 62  6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-03-24
# 64  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-01
# 65  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-03-06
# 67  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-18
# 69  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-04-06
# 70  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-03-22
# 71  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-03-03
# 73  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-03-03
# 74  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-03
# 75  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-04-14
# 76  6a2b8b6d17b0933836c1f976  Milenna Xavier            NaN          NaT
#
#    data_inicio status_atual data_conclusao  \
# 1   2026-03-27    concluida     2026-04-02
# 2   2026-03-27    concluida     2026-04-06
# 3   2026-04-21    concluida     2026-04-27
# 4   2026-03-05    concluida     2026-03-19
# 7   2026-04-21    concluida     2026-04-30
# 9   2026-03-29    concluida     2026-04-09
# 10  2026-03-05    concluida     2026-03-12
# 11  2026-03-12    concluida     2026-03-25
# 12  2026-05-10    concluida     2026-05-18
# 13  2026-04-16    concluida     2026-05-01
# 14  2026-04-23    concluida     2026-05-10
# 16  2026-04-01    concluida     2026-04-07
# 19  2026-03-25    concluida     2026-04-03
# 20  2026-03-28    concluida     2026-04-17
# 21  2026-03-22    concluida     2026-04-01
# 22  2026-04-22    concluida     2026-04-29
# 30  2026-05-11    concluida     2026-05-31
# 31  2026-03-08    concluida     2026-03-13
# 32  2026-03-27    concluida     2026-04-01
# 33  2026-04-01    concluida     2026-04-16
# 35  2026-03-13    concluida     2026-03-29
# 39  2026-03-26    concluida     2026-04-01
# 41  2026-03-04    concluida     2026-03-11
# 43  2026-05-04    concluida     2026-05-20
# 44  2026-03-03    concluida     2026-03-18
# 48  2026-04-01    concluida     2026-04-15
# 50  2026-03-14    concluida     2026-03-28
# 51  2026-03-17    concluida     2026-03-30
# 52  2026-04-27    concluida     2026-05-16
# 54  2026-04-28    concluida     2026-05-13
# 58  2026-03-11    concluida     2026-03-15
# 59  2026-04-11    concluida     2026-04-17
# 61  2026-03-12    concluida     2026-04-01
# 62  2026-03-25    concluida     2026-04-05
# 64  2026-05-04    concluida     2026-05-18
# 65  2026-03-08    concluida     2026-03-12
# 67  2026-03-19    concluida     2026-03-22
# 69  2026-04-07    concluida     2026-04-11
# 70  2026-03-25    concluida     2026-04-05
# 71  2026-03-04    concluida     2026-03-23
# 73  2026-03-04    concluida     2026-03-09
# 74  2026-05-06    concluida     2026-05-10
# 75  2026-04-16    concluida     2026-04-25
# 76  2026-06-11    concluida     2026-06-15
#
#                          feedback_conclusao_mentorado  duracao_em_dias
# 1   Os testes cobriram os cenários críticos de aut...              6.0
# 2   Validação executada com sucesso. O fluxo corre...             10.0
# 3   Conseguimos manter uma boa cobertura de testes...              6.0
# 4   Os ajustes visuais foram concluídos no prazo. ...             14.0
# 7   Atividade finalizada com sucesso. A automação ...              9.0
# 9   Interface montada conforme o protótipo. O dese...             11.0
# 10  Otimizamos o tempo total do fluxo de integraçã...              7.0
# 11  A separação aumentou a legibilidade do código....             13.0
# 12  Adicionamos criptografia rígida e otimizamos a...              8.0
# 13  Dicionário de dados atualizado com sucesso no ...             15.0
# 14  Pipeline criado do zero para os novos serviços...             17.0
# 16  Entregamos a visualização consolidada de métri...              6.0
# 19  A refatoração limpou chaves redundantes e otim...              9.0
# 20  Eliminamos acoplamentos ruins e centralizamos ...             20.0
# 21  Documentação finalizada englobando os esquemas...             10.0
# 22  A revisão profunda ajudou a identificar brecha...              7.0
# 30  Adicionamos notificações via Slack e tratament...             20.0
# 31  Ajustamos os gatilhos para evitar deploys acid...              5.0
# 32  A análise identificou uma alta taxa de duplica...              5.0
# 33  Validamos todos os novos índices criados para ...             15.0
# 35  A migração da SDK foi implementada. A maior ba...             16.0
# 39  Adicionamos o mecanismo de refresh token. Isso...              6.0
# 41  Conseguimos adicionar filtros por data de cria...              7.0
# 43  Análise focada em otimização de performance co...             16.0
# 44  Os cenários cobriram relatórios vazios ou lota...             15.0
# 48  Validamos buscas complexas cruzando múltiplos ...             14.0
# 50  Finalizei as telas de gerenciamento de prazos ...             14.0
# 51  Focamos em testes de segurança contra força br...             13.0
# 52  Limpamos as configurações antigas que estavam ...             19.0
# 54  A análise apontou problemas de contraste em bo...             15.0
# 58  Identificamos consultas pesadas no back-end di...              4.0
# 59  Corrigi os testes intermitentes que quebravam ...              6.0
# 61  Montamos o catálogo descritivo e visual no Sto...             20.0
# 62  Revisamos as interações feitas por navegação p...             11.0
# 64  A otimização reduziu pela metade os acessos di...             14.0
# 65  Guia completo descrevendo a arquitetura e chav...              4.0
# 67  Documentamos as propriedades esperadas e casos...              3.0
# 69  Geramos os manuais de rotas e payloads aceitos...              4.0
# 70  Ajustamos o isolamento seguro de chaves sensív...             11.0
# 71  Removemos etapas de compilação redundantes e r...             19.0
# 73  Corrigimos os estouros visuais de layout que o...              5.0
# 74  Atualizamos os endpoints centrais de login par...              4.0
# 75  Focamos na melhoria do tratamento do timeout d...              9.0
# 76  Integração realizada com sucesso. A refatoraçã...              4.0
# ===========
#    task_id                                         titulo prioridade  \
# 0      1.0             Otimizar Microsserviços - Sprint 8      media
# 5      6.0    Documentar Acessibilidade (WCAG) - Sprint 7      baixa
# 8      9.0     Atualizar Acessibilidade (WCAG) - Sprint 1      media
# 17    18.0       Implementar Scripts de Deploy - Sprint 1       alta
# 18    19.0            Criar Componentes React - Sprint 10       alta
# 23    24.0            Testar Scripts de Deploy - Sprint 2       alta
# 24    25.0      Otimizar Fluxo de Autenticação - Sprint 8       alta
# 25    26.0         Atualizar Componentes React - Sprint 5      media
# 37    38.0    Documentar Acessibilidade (WCAG) - Sprint 4      baixa
# 38    39.0            Testar Componentes React - Sprint 9      media
# 45    46.0            Testar Scripts de Deploy - Sprint 2       alta
# 46    47.0        Testar Fluxo de Autenticação - Sprint 3       alta
# 49    50.0                Criar Pipeline CI/CD - Sprint 7       alta
# 53    54.0   Implementar Fluxo de Autenticação - Sprint 1       alta
# 57    58.0  Implementar Fluxo de Autenticação - Sprint 10       alta
# 60    61.0           Ajustar Componentes React - Sprint 2       alta
# 63    64.0  Atualizar Exportação de Relatórios - Sprint 1      media
# 66    67.0         Atualizar Scripts de Deploy - Sprint 9       alta
# 68    69.0         Criar Fluxo de Autenticação - Sprint 5       alta
#
#                      user_id       mentorado   area_atuacao data_criacao  \
# 0   6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-05
# 5   6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-05-05
# 8   6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-05-05
# 17  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-12
# 18  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-05-21
# 23  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-05-08
# 24  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-19
# 25  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-05-06
# 37  6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-05-12
# 38  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-03
# 45  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-03
# 46  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-05-05
# 49  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-25
# 53  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-25
# 57  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-09
# 60  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-05-09
# 63  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-18
# 66  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-25
# 68  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-19
#
#    data_inicio status_atual data_conclusao feedback_conclusao_mentorado  \
# 0   2026-05-07    andamento            NaT                          NaN
# 5   2026-05-07    andamento            NaT                          NaN
# 8   2026-05-07    andamento            NaT                          NaN
# 17  2026-05-17    andamento            NaT                          NaN
# 18  2026-05-21    andamento            NaT                          NaN
# 23  2026-05-11    andamento            NaT                          NaN
# 24  2026-05-19    andamento            NaT                          NaN
# 25  2026-05-10    andamento            NaT                          NaN
# 37  2026-05-15    andamento            NaT                          NaN
# 38  2026-05-08    andamento            NaT                          NaN
# 45  2026-05-08    andamento            NaT                          NaN
# 46  2026-05-07    andamento            NaT                          NaN
# 49  2026-05-29    andamento            NaT                          NaN
# 53  2026-05-25    andamento            NaT                          NaN
# 57  2026-05-09    andamento            NaT                          NaN
# 60  2026-05-13    andamento            NaT                          NaN
# 63  2026-05-22    andamento            NaT                          NaN
# 66  2026-05-26    andamento            NaT                          NaN
# 68  2026-05-21    andamento            NaT                          NaN
#
#     duracao_em_dias
# 0              24.0
# 5              24.0
# 8              24.0
# 17             14.0
# 18             10.0
# 23             20.0
# 24             12.0
# 25             21.0
# 37             16.0
# 38             23.0
# 45             23.0
# 46             24.0
# 49              2.0
# 53              6.0
# 57             22.0
# 60             18.0
# 63              9.0
# 66              5.0
# 68             10.0
# ===========
#    task_id                                            titulo prioridade  \
# 6      7.0                    Criar API de Login - Sprint 10       alta
# 15    16.0    Documentar Exportação de Relatórios - Sprint 9      baixa
# 26    27.0                     Criar API de Login - Sprint 2       alta
# 27    28.0           Implementar Filtros de Busca - Sprint 3       alta
# 28    29.0                       Testar Dashboard - Sprint 6      media
# 29    30.0             Criar Testes de Integração - Sprint 5       alta
# 34    35.0              Implementar Tabelas no BD - Sprint 5       alta
# 36    37.0                Otimizar Pipeline CI/CD - Sprint 2      media
# 40    41.0     Otimizar Exportação de Relatórios - Sprint 10      media
# 42    43.0                  Testar Pipeline CI/CD - Sprint 4      media
# 47    48.0                Analisar Pipeline CI/CD - Sprint 2      baixa
# 55    56.0                Analisar Microsserviços - Sprint 6      baixa
# 56    57.0             Otimizar Scripts de Deploy - Sprint 8       alta
# 72    73.0  Implementar Exportação de Relatórios - Sprint 10      media
#
#                      user_id       mentorado   area_atuacao data_criacao  \
# 6   6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-17
# 15  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-26
# 26  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-26
# 27  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-27
# 28  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-15
# 29  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-14
# 34  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-14
# 36  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-10
# 40  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-18
# 42  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-27
# 47  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-05-11
# 55  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-26
# 56  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-27
# 72  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-11
#
#    data_inicio status_atual data_conclusao feedback_conclusao_mentorado  \
# 6          NaT     pendente            NaT                          NaN
# 15         NaT     pendente            NaT                          NaN
# 26         NaT     pendente            NaT                          NaN
# 27         NaT     pendente            NaT                          NaN
# 28         NaT     pendente            NaT                          NaN
# 29         NaT     pendente            NaT                          NaN
# 34         NaT     pendente            NaT                          NaN
# 36         NaT     pendente            NaT                          NaN
# 40         NaT     pendente            NaT                          NaN
# 42         NaT     pendente            NaT                          NaN
# 47         NaT     pendente            NaT                          NaN
# 55         NaT     pendente            NaT                          NaN
# 56         NaT     pendente            NaT                          NaN
# 72         NaT     pendente            NaT                          NaN
#
#     duracao_em_dias
# 6              14.0
# 15              5.0
# 26              5.0
# 27              4.0
# 28             16.0
# 29             17.0
# 34             17.0
# 36             21.0
# 40             13.0
# 42              4.0
# 47             20.0
# 55              5.0
# 56              4.0
# 72             20.0

# %%
tabela.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   task_id                       76 non-null     object
#  1   titulo                        77 non-null     str
#  2   prioridade                    77 non-null     str
#  3   user_id                       77 non-null     object
#  4   mentorado                     77 non-null     str
#  5   area_atuacao                  76 non-null     str
#  6   data_criacao                  76 non-null     datetime64[us]
#  7   data_inicio                   63 non-null     datetime64[us]
#  8   status_atual                  77 non-null     str
#  9   data_conclusao                44 non-null     datetime64[us]
#  10  feedback_conclusao_mentorado  44 non-null     str
#  11  duracao_em_dias               77 non-null     float64
# dtypes: datetime64[us](3), float64(1), object(2), str(6)
# memory usage: 7.3+ KB

# %%
tabela['status_atual'].value_counts()
print(f'{tabela["status_atual"].value_counts()}')

#agr sabemos como estao as atividades e os status gerais
# Out:
# status_atual
# concluida    44
# andamento    19
# pendente     14
# Name: count, dtype: int64

# %%
#
tabela['status_atual'].value_counts(normalize=True) * 100
# Out:
# status_atual
# concluida    57.142857
# andamento    24.675325
# pendente     18.181818
# Name: proportion, dtype: float64

# %%
#distribuição de status_atual por mentorado
tabela.groupby('mentorado')['status_atual'].value_counts(normalize=True) * 100

#podemos tirar daqui q o caount nos mostra quantas vezes os mentorados tem atividade
# Out:
# mentorado       status_atual
# Ana Ribeiro     concluida        62.500000
#                 pendente         18.750000
#                 andamento        18.750000
# Bruno Costa     concluida        70.000000
#                 pendente         20.000000
#                 andamento        10.000000
# Camila Lopes    concluida        42.857143
#                 pendente         42.857143
#                 andamento        14.285714
# Diego Martins   pendente         44.444444
#                 concluida        33.333333
#                 andamento        22.222222
# Eduarda Souza   concluida        70.000000
#                 andamento        30.000000
# Felipe Andrade  concluida        70.000000
#                 andamento        20.000000
#                 pendente         10.000000
# Gabriela Pinto  concluida        50.000000
#                 andamento        40.000000
#                 pendente         10.000000
# Henrique Alves  andamento        75.000000
#                 concluida        25.000000
# Milenna Xavier  concluida       100.000000
# Name: proportion, dtype: float64

# %%
tabela.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           77 non-null     object
#  1   task_id                       76 non-null     object
#  2   titulo                        77 non-null     str
#  3   prioridade                    77 non-null     str
#  4   user_id                       77 non-null     object
#  5   mentorado                     77 non-null     str
#  6   area_atuacao                  76 non-null     str
#  7   data_criacao                  76 non-null     datetime64[us]
#  8   data_inicio                   63 non-null     datetime64[us]
#  9   status_atual                  77 non-null     str
#  10  data_conclusao                44 non-null     datetime64[us]
#  11  feedback_conclusao_mentorado  44 non-null     str
#  12  createdAt                     1 non-null      datetime64[us]
#  13  updatedAt                     1 non-null      datetime64[us]
#  14  __v                           1 non-null      float64
#  15  duracao_em_dias               77 non-null     float64
# dtypes: datetime64[us](5), float64(2), object(3), str(6)
# memory usage: 9.8+ KB

# %%
media_por_prioridade = tabela.groupby('prioridade')['duracao_em_dias'].mean().round(1)
print(media_por_prioridade)
mediana_por_prioridade = tabela.groupby('prioridade')['duracao_em_dias'].median().round(1)
print(mediana_por_prioridade)
# Out:
# prioridade
# alta     11.3
# baixa    11.6
# media    13.5
# Name: duracao_em_dias, dtype: float64
# prioridade
# alta     10.0
# baixa    12.5
# media    14.0
# Name: duracao_em_dias, dtype: float64

# %% [markdown]
# #EDA -  MENTORADA

# %%
mentorada = tabela[tabela['mentorado'] == 'Ana Ribeiro'].copy()
mentorada.head(16)
# Out:
#                          _id task_id  \
# 7   6a2b884993a2aac46c8ba151     8.0
# 10  6a2b884993a2aac46c8ba154    11.0
# 13  6a2b884993a2aac46c8ba157    14.0
# 14  6a2b884993a2aac46c8ba158    15.0
# 17  6a2b884993a2aac46c8ba15b    18.0
# 21  6a2b884993a2aac46c8ba15f    22.0
# 30  6a2b884993a2aac46c8ba168    31.0
# 31  6a2b884993a2aac46c8ba169    32.0
# 34  6a2b884993a2aac46c8ba16c    35.0
# 36  6a2b884993a2aac46c8ba16e    37.0
# 49  6a2b884993a2aac46c8ba17b    50.0
# 52  6a2b884993a2aac46c8ba17e    53.0
# 56  6a2b884993a2aac46c8ba182    57.0
# 66  6a2b884993a2aac46c8ba18c    67.0
# 70  6a2b884993a2aac46c8ba190    71.0
# 71  6a2b884993a2aac46c8ba191    72.0
#
#                                       titulo prioridade  \
# 7         Criar Scripts de Deploy - Sprint 2       alta
# 10       Atualizar Pipeline CI/CD - Sprint 1      media
# 13       Documentar Tabelas no BD - Sprint 4      baixa
# 14           Criar Pipeline CI/CD - Sprint 6       alta
# 17  Implementar Scripts de Deploy - Sprint 1       alta
# 21       Documentar Tabelas no BD - Sprint 6      baixa
# 30    Atualizar Scripts de Deploy - Sprint 6       alta
# 31         Ajustar Pipeline CI/CD - Sprint 9       alta
# 34      Implementar Tabelas no BD - Sprint 5       alta
# 36        Otimizar Pipeline CI/CD - Sprint 2      media
# 49           Criar Pipeline CI/CD - Sprint 7       alta
# 52    Refatorar Scripts de Deploy - Sprint 5       alta
# 56     Otimizar Scripts de Deploy - Sprint 8       alta
# 66    Atualizar Scripts de Deploy - Sprint 9       alta
# 70         Ajustar Pipeline CI/CD - Sprint 2       alta
# 71       Refatorar Pipeline CI/CD - Sprint 7      media
#
#                      user_id    mentorado   area_atuacao data_criacao  \
# 7   6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-04-20
# 10  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-03-04
# 13  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-04-15
# 14  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-04-21
# 17  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-12
# 21  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-03-20
# 30  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-08
# 31  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-03-05
# 34  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-14
# 36  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-10
# 49  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-25
# 52  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-04-24
# 56  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-27
# 66  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-25
# 70  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-03-22
# 71  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-03-03
#
#    data_inicio status_atual data_conclusao  \
# 7   2026-04-21    concluida     2026-04-30
# 10  2026-03-05    concluida     2026-03-12
# 13  2026-04-16    concluida     2026-05-01
# 14  2026-04-23    concluida     2026-05-10
# 17  2026-05-17    andamento            NaT
# 21  2026-03-22    concluida     2026-04-01
# 30  2026-05-11    concluida     2026-05-31
# 31  2026-03-08    concluida     2026-03-13
# 34         NaT     pendente            NaT
# 36         NaT     pendente            NaT
# 49  2026-05-29    andamento            NaT
# 52  2026-04-27    concluida     2026-05-16
# 56         NaT     pendente            NaT
# 66  2026-05-26    andamento            NaT
# 70  2026-03-25    concluida     2026-04-05
# 71  2026-03-04    concluida     2026-03-23
#
#                          feedback_conclusao_mentorado createdAt updatedAt  \
# 7   Atividade finalizada com sucesso. A automação ...       NaT       NaT
# 10  Otimizamos o tempo total do fluxo de integraçã...       NaT       NaT
# 13  Dicionário de dados atualizado com sucesso no ...       NaT       NaT
# 14  Pipeline criado do zero para os novos serviços...       NaT       NaT
# 17                                                NaN       NaT       NaT
# 21  Documentação finalizada englobando os esquemas...       NaT       NaT
# 30  Adicionamos notificações via Slack e tratament...       NaT       NaT
# 31  Ajustamos os gatilhos para evitar deploys acid...       NaT       NaT
# 34                                                NaN       NaT       NaT
# 36                                                NaN       NaT       NaT
# 49                                                NaN       NaT       NaT
# 52  Limpamos as configurações antigas que estavam ...       NaT       NaT
# 56                                                NaN       NaT       NaT
# 66                                                NaN       NaT       NaT
# 70  Ajustamos o isolamento seguro de chaves sensív...       NaT       NaT
# 71  Removemos etapas de compilação redundantes e r...       NaT       NaT
#
#     __v  duracao_em_dias
# 7   NaN              9.0
# 10  NaN              7.0
# 13  NaN             15.0
# 14  NaN             17.0
# 17  NaN             14.0
# 21  NaN             10.0
# 30  NaN             20.0
# 31  NaN              5.0
# 34  NaN             17.0
# 36  NaN             21.0
# 49  NaN              2.0
# 52  NaN             19.0
# 56  NaN              4.0
# 66  NaN              5.0
# 70  NaN             11.0
# 71  NaN             19.0

# %%
media_prioridade_Ana = mentorada.groupby('prioridade')['duracao_em_dias'].mean().round(1)
print(media_prioridade_Ana)
# Out:
# prioridade
# alta     11.2
# baixa    12.5
# media    15.7
# Name: duracao_em_dias, dtype: float64

# %%
media_por_status_ana = mentorada.groupby('status_atual')['duracao_em_dias'].mean().round(1)
print(media_por_status_ana)
# Out:
# status_atual
# andamento     7.0
# concluida    13.2
# pendente     14.0
# Name: duracao_em_dias, dtype: float64

# %%
mentorada.describe()
# Out:
#               data_criacao                 data_inicio       data_conclusao  \
# count                   16                          13                   10
# mean   2026-04-19 09:00:00  2026-04-15 07:23:04.615384  2026-04-16 21:36:00
# min    2026-03-03 00:00:00         2026-03-04 00:00:00  2026-03-12 00:00:00
# 25%    2026-03-21 12:00:00         2026-03-22 00:00:00  2026-03-25 06:00:00
# 50%    2026-04-22 12:00:00         2026-04-21 00:00:00  2026-04-17 12:00:00
# 75%    2026-05-12 12:00:00         2026-05-11 00:00:00  2026-05-07 18:00:00
# max    2026-05-27 00:00:00         2026-05-29 00:00:00  2026-05-31 00:00:00
# std                    NaN                         NaN                  NaN
#
#       createdAt updatedAt  __v  duracao_em_dias
# count         0         0  0.0        16.000000
# mean        NaT       NaT  NaN        12.187500
# min         NaT       NaT  NaN         2.000000
# 25%         NaT       NaT  NaN         6.500000
# 50%         NaT       NaT  NaN        12.500000
# 75%         NaT       NaT  NaN        17.500000
# max         NaT       NaT  NaN        21.000000
# std         NaN       NaN  NaN         6.358393

# %%
duracao_em_dias_series = mentorada['duracao_em_dias']

duracao_em_dias_series.quantile([0.25, 0.5, 0.75])
IQR = duracao_em_dias_series.quantile(0.75) - duracao_em_dias_series.quantile(0.25)
print(IQR)
Q1 = duracao_em_dias_series.quantile(0.25)
Q3 = duracao_em_dias_series.quantile(0.75)
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR
print(f'Limite Inferior: {limite_inferior}')
print(f'Limite Superior: {limite_superior}')
# Out:
# 11.0
# Limite Inferior: -10.0
# Limite Superior: 34.0

# %%
historico = tabela[tabela['status_atual'] == 'concluida']# vai se basear nas entregas do geral de mentorados
media_geral_por_prioridade = historico.groupby('prioridade')['duracao_em_dias'].mean().round(0) #usamos os dados do dataset geral
print(media_geral_por_prioridade)


tarefas_ativas = mentorada[mentorada['status_atual'].isin(['andamento', 'pendente'])].copy()
tarefas_ativas['tempo_limite'] = tarefas_ativas['prioridade'].map(media_geral_por_prioridade) # O .map() olha a prioridade da tarefa e "cola" o tempo limite exato na coluna ao lado.
print(tarefas_ativas)
# Out:
# prioridade
# alta     10.0
# baixa    10.0
# media    11.0
# Name: duracao_em_dias, dtype: float64
#                          _id task_id  \
# 17  6a2b884993a2aac46c8ba15b    18.0
# 34  6a2b884993a2aac46c8ba16c    35.0
# 36  6a2b884993a2aac46c8ba16e    37.0
# 49  6a2b884993a2aac46c8ba17b    50.0
# 56  6a2b884993a2aac46c8ba182    57.0
# 66  6a2b884993a2aac46c8ba18c    67.0
#
#                                       titulo prioridade  \
# 17  Implementar Scripts de Deploy - Sprint 1       alta
# 34      Implementar Tabelas no BD - Sprint 5       alta
# 36        Otimizar Pipeline CI/CD - Sprint 2      media
# 49           Criar Pipeline CI/CD - Sprint 7       alta
# 56     Otimizar Scripts de Deploy - Sprint 8       alta
# 66    Atualizar Scripts de Deploy - Sprint 9       alta
#
#                      user_id    mentorado   area_atuacao data_criacao  \
# 17  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-12
# 34  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-14
# 36  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-10
# 49  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-25
# 56  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-27
# 66  6a2b84ddcf36b576d237ae70  Ana Ribeiro  Data Engineer   2026-05-25
#
#    data_inicio status_atual data_conclusao feedback_conclusao_mentorado  \
# 17  2026-05-17    andamento            NaT                          NaN
# 34         NaT     pendente            NaT                          NaN
# 36         NaT     pendente            NaT                          NaN
# 49  2026-05-29    andamento            NaT                          NaN
# 56         NaT     pendente            NaT                          NaN
# 66  2026-05-26    andamento            NaT                          NaN
#
#    createdAt updatedAt  __v  duracao_em_dias  tempo_limite
# 17       NaT       NaT  NaN             14.0          10.0
# 34       NaT       NaT  NaN             17.0          10.0
# 36       NaT       NaT  NaN             21.0          11.0
# 49       NaT       NaT  NaN              2.0          10.0
# 56       NaT       NaT  NaN              4.0          10.0
# 66       NaT       NaT  NaN              5.0          10.0

# %%
historico = tabela[tabela['status_atual'] == 'concluida']# vai se basear nas entregas do geral de mentorados
media_geral_por_prioridade = historico.groupby('prioridade')['duracao_em_dias'].mean().round(0) #usamos os dados do dataset geral
print(media_geral_por_prioridade)


tarefas_ativas = tabela[tabela['status_atual'].isin(['andamento', 'pendente'])].copy()
tarefas_ativas['tempo_limite'] = tarefas_ativas['prioridade'].map(media_geral_por_prioridade) # O .map() olha a prioridade da tarefa e "cola" o tempo limite exato na coluna ao lado.
print(tarefas_ativas)
# Out:
# prioridade
# alta     10.0
# baixa    10.0
# media    11.0
# Name: duracao_em_dias, dtype: float64
#                          _id task_id  \
# 0   6a2b884993a2aac46c8ba14a     1.0
# 5   6a2b884993a2aac46c8ba14f     6.0
# 6   6a2b884993a2aac46c8ba150     7.0
# 8   6a2b884993a2aac46c8ba152     9.0
# 15  6a2b884993a2aac46c8ba159    16.0
# 17  6a2b884993a2aac46c8ba15b    18.0
# 18  6a2b884993a2aac46c8ba15c    19.0
# 23  6a2b884993a2aac46c8ba161    24.0
# 24  6a2b884993a2aac46c8ba162    25.0
# 25  6a2b884993a2aac46c8ba163    26.0
# 26  6a2b884993a2aac46c8ba164    27.0
# 27  6a2b884993a2aac46c8ba165    28.0
# 28  6a2b884993a2aac46c8ba166    29.0
# 29  6a2b884993a2aac46c8ba167    30.0
# 34  6a2b884993a2aac46c8ba16c    35.0
# 36  6a2b884993a2aac46c8ba16e    37.0
# 37  6a2b884993a2aac46c8ba16f    38.0
# 38  6a2b884993a2aac46c8ba170    39.0
# 40  6a2b884993a2aac46c8ba172    41.0
# 42  6a2b884993a2aac46c8ba174    43.0
# 45  6a2b884993a2aac46c8ba177    46.0
# 46  6a2b884993a2aac46c8ba178    47.0
# 47  6a2b884993a2aac46c8ba179    48.0
# 49  6a2b884993a2aac46c8ba17b    50.0
# 53  6a2b884993a2aac46c8ba17f    54.0
# 55  6a2b884993a2aac46c8ba181    56.0
# 56  6a2b884993a2aac46c8ba182    57.0
# 57  6a2b884993a2aac46c8ba183    58.0
# 60  6a2b884993a2aac46c8ba186    61.0
# 63  6a2b884993a2aac46c8ba189    64.0
# 66  6a2b884993a2aac46c8ba18c    67.0
# 68  6a2b884993a2aac46c8ba18e    69.0
# 72  6a2b884993a2aac46c8ba192    73.0
#
#                                               titulo prioridade  \
# 0                 Otimizar Microsserviços - Sprint 8      media
# 5        Documentar Acessibilidade (WCAG) - Sprint 7      baixa
# 6                     Criar API de Login - Sprint 10       alta
# 8         Atualizar Acessibilidade (WCAG) - Sprint 1      media
# 15    Documentar Exportação de Relatórios - Sprint 9      baixa
# 17          Implementar Scripts de Deploy - Sprint 1       alta
# 18               Criar Componentes React - Sprint 10       alta
# 23               Testar Scripts de Deploy - Sprint 2       alta
# 24         Otimizar Fluxo de Autenticação - Sprint 8       alta
# 25            Atualizar Componentes React - Sprint 5      media
# 26                     Criar API de Login - Sprint 2       alta
# 27           Implementar Filtros de Busca - Sprint 3       alta
# 28                       Testar Dashboard - Sprint 6      media
# 29             Criar Testes de Integração - Sprint 5       alta
# 34              Implementar Tabelas no BD - Sprint 5       alta
# 36                Otimizar Pipeline CI/CD - Sprint 2      media
# 37       Documentar Acessibilidade (WCAG) - Sprint 4      baixa
# 38               Testar Componentes React - Sprint 9      media
# 40     Otimizar Exportação de Relatórios - Sprint 10      media
# 42                  Testar Pipeline CI/CD - Sprint 4      media
# 45               Testar Scripts de Deploy - Sprint 2       alta
# 46           Testar Fluxo de Autenticação - Sprint 3       alta
# 47                Analisar Pipeline CI/CD - Sprint 2      baixa
# 49                   Criar Pipeline CI/CD - Sprint 7       alta
# 53      Implementar Fluxo de Autenticação - Sprint 1       alta
# 55                Analisar Microsserviços - Sprint 6      baixa
# 56             Otimizar Scripts de Deploy - Sprint 8       alta
# 57     Implementar Fluxo de Autenticação - Sprint 10       alta
# 60              Ajustar Componentes React - Sprint 2       alta
# 63     Atualizar Exportação de Relatórios - Sprint 1      media
# 66            Atualizar Scripts de Deploy - Sprint 9       alta
# 68            Criar Fluxo de Autenticação - Sprint 5       alta
# 72  Implementar Exportação de Relatórios - Sprint 10      media
#
#                      user_id       mentorado   area_atuacao data_criacao  \
# 0   6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-05
# 5   6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-05-05
# 6   6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-17
# 8   6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-05-05
# 15  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-26
# 17  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-12
# 18  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-05-21
# 23  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-05-08
# 24  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-19
# 25  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-05-06
# 26  6a2b8445cf36b576d237ae6b     Bruno Costa    DevBack-end   2026-05-26
# 27  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-27
# 28  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-15
# 29  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-14
# 34  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-14
# 36  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-10
# 37  6a2b84cbcf36b576d237ae6f  Henrique Alves  UX/UIDesigner   2026-05-12
# 38  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-03
# 40  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-18
# 42  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-27
# 45  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-03
# 46  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-05-05
# 47  6a2b8468cf36b576d237ae6c  Felipe Andrade             QA   2026-05-11
# 49  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-25
# 53  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-25
# 55  6a2b8496cf36b576d237ae6d   Diego Martins             QA   2026-05-26
# 56  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-27
# 57  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-09
# 60  6a2b84eecf36b576d237ae71   Eduarda Souza   DevFront-end   2026-05-09
# 63  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-18
# 66  6a2b84ddcf36b576d237ae70     Ana Ribeiro  Data Engineer   2026-05-25
# 68  6a2b8501cf36b576d237ae72  Gabriela Pinto      DevMobile   2026-05-19
# 72  6a2b84b4cf36b576d237ae6e    Camila Lopes        Produto   2026-05-11
#
#    data_inicio status_atual data_conclusao feedback_conclusao_mentorado  \
# 0   2026-05-07    andamento            NaT                          NaN
# 5   2026-05-07    andamento            NaT                          NaN
# 6          NaT     pendente            NaT                          NaN
# 8   2026-05-07    andamento            NaT                          NaN
# 15         NaT     pendente            NaT                          NaN
# 17  2026-05-17    andamento            NaT                          NaN
# 18  2026-05-21    andamento            NaT                          NaN
# 23  2026-05-11    andamento            NaT                          NaN
# 24  2026-05-19    andamento            NaT                          NaN
# 25  2026-05-10    andamento            NaT                          NaN
# 26         NaT     pendente            NaT                          NaN
# 27         NaT     pendente            NaT                          NaN
# 28         NaT     pendente            NaT                          NaN
# 29         NaT     pendente            NaT                          NaN
# 34         NaT     pendente            NaT                          NaN
# 36         NaT     pendente            NaT                          NaN
# 37  2026-05-15    andamento            NaT                          NaN
# 38  2026-05-08    andamento            NaT                          NaN
# 40         NaT     pendente            NaT                          NaN
# 42         NaT     pendente            NaT                          NaN
# 45  2026-05-08    andamento            NaT                          NaN
# 46  2026-05-07    andamento            NaT                          NaN
# 47         NaT     pendente            NaT                          NaN
# 49  2026-05-29    andamento            NaT                          NaN
# 53  2026-05-25    andamento            NaT                          NaN
# 55         NaT     pendente            NaT                          NaN
# 56         NaT     pendente            NaT                          NaN
# 57  2026-05-09    andamento            NaT                          NaN
# 60  2026-05-13    andamento            NaT                          NaN
# 63  2026-05-22    andamento            NaT                          NaN
# 66  2026-05-26    andamento            NaT                          NaN
# 68  2026-05-21    andamento            NaT                          NaN
# 72         NaT     pendente            NaT                          NaN
#
#    createdAt updatedAt  __v  duracao_em_dias  tempo_limite
# 0        NaT       NaT  NaN             24.0          11.0
# 5        NaT       NaT  NaN             24.0          10.0
# 6        NaT       NaT  NaN             14.0          10.0
# 8        NaT       NaT  NaN             24.0          11.0
# 15       NaT       NaT  NaN              5.0          10.0
# 17       NaT       NaT  NaN             14.0          10.0
# 18       NaT       NaT  NaN             10.0          10.0
# 23       NaT       NaT  NaN             20.0          10.0
# 24       NaT       NaT  NaN             12.0          10.0
# 25       NaT       NaT  NaN             21.0          11.0
# 26       NaT       NaT  NaN              5.0          10.0
# 27       NaT       NaT  NaN              4.0          10.0
# 28       NaT       NaT  NaN             16.0          11.0
# 29       NaT       NaT  NaN             17.0          10.0
# 34       NaT       NaT  NaN             17.0          10.0
# 36       NaT       NaT  NaN             21.0          11.0
# 37       NaT       NaT  NaN             16.0          10.0
# 38       NaT       NaT  NaN             23.0          11.0
# 40       NaT       NaT  NaN             13.0          11.0
# 42       NaT       NaT  NaN              4.0          11.0
# 45       NaT       NaT  NaN             23.0          10.0
# 46       NaT       NaT  NaN             24.0          10.0
# 47       NaT       NaT  NaN             20.0          10.0
# 49       NaT       NaT  NaN              2.0          10.0
# 53       NaT       NaT  NaN              6.0          10.0
# 55       NaT       NaT  NaN              5.0          10.0
# 56       NaT       NaT  NaN              4.0          10.0
# 57       NaT       NaT  NaN             22.0          10.0
# 60       NaT       NaT  NaN             18.0          10.0
# 63       NaT       NaT  NaN              9.0          11.0
# 66       NaT       NaT  NaN              5.0          10.0
# 68       NaT       NaT  NaN             10.0          10.0
# 72       NaT       NaT  NaN             20.0          11.0

# %%
mentorada.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16 entries, 7 to 71
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           16 non-null     object
#  1   task_id                       16 non-null     object
#  2   titulo                        16 non-null     str
#  3   prioridade                    16 non-null     str
#  4   user_id                       16 non-null     object
#  5   mentorado                     16 non-null     str
#  6   area_atuacao                  16 non-null     str
#  7   data_criacao                  16 non-null     datetime64[us]
#  8   data_inicio                   13 non-null     datetime64[us]
#  9   status_atual                  16 non-null     str
#  10  data_conclusao                10 non-null     datetime64[us]
#  11  feedback_conclusao_mentorado  10 non-null     str
#  12  createdAt                     0 non-null      datetime64[us]
#  13  updatedAt                     0 non-null      datetime64[us]
#  14  __v                           0 non-null      float64
#  15  duracao_em_dias               16 non-null     float64
# dtypes: datetime64[us](5), float64(2), object(3), str(6)
# memory usage: 2.1+ KB

# %%
mentorada.isnull().sum()
# Out:
# _id                              0
# task_id                          0
# titulo                           0
# prioridade                       0
# user_id                          0
# mentorado                        0
# area_atuacao                     0
# data_criacao                     0
# data_inicio                      3
# status_atual                     0
# data_conclusao                   6
# feedback_conclusao_mentorado     6
# createdAt                       16
# updatedAt                       16
# __v                             16
# duracao_em_dias                  0
# dtype: int64

# %%
mentorada.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #GRAFICOS

# %% [markdown]
# ##card - valores totais, médias gerais, ou algo muito expecidfico

# %%
datacorte = pd.to_datetime('2026-05-31') #valor para parametro de atvs n iniciadas ou em andamento, ja sabemos as atvds q foram finalizadas

# %%
#CARD total de atividade escaladas(sugestao)
import matplotlib.pyplot as plt
mentorada['status_atual'].count()
print(f'O total de atividade de Ana é: {mentorada["status_atual"].count()}')


fig, ax = plt.subplots(figsize=(4, 2))
ax.patch.set_facecolor('#f4f4f4')
fig.patch.set_facecolor('#f4f4f4')

# Remover bordas
for spine in ax.spines.values():
    spine.set_visible(False)

# Remover eixos
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# Textos do card (métrica e label)
ax.text(0.5, 0.65, '16', fontsize=30, fontweight='bold', ha='center', color='#333333')
ax.text(0.5, 0.35, 'total de atividades no trimestre', fontsize=14, ha='center', color='#777777')

plt.tight_layout()
plt.show()
# Out:
# O total de atividade de Ana é: 16

# %%
#card total de atividades concluidas no trimestre
total_concluidas = mentorada[mentorada['status_atual'] == 'concluida'].shape[0]
print(f'Total de atividade concluidas de Ana é: {total_concluidas}')

fig, ax = plt.subplots(figsize=(4, 2))
ax.patch.set_facecolor('#f4f4f4')
fig.patch.set_facecolor('#f4f4f4')

# Remover bordas
for spine in ax.spines.values():
    spine.set_visible(False)

# Remover eixos
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# Textos do card (métrica e label)
ax.text(0.5, 0.65, str(total_concluidas), fontsize=30, fontweight='bold', ha='center', color='#333333')
ax.text(0.5, 0.35, 'total de atividades concluídas', fontsize=14, ha='center', color='#777777')

plt.tight_layout()
plt.show()
# Out:
# Total de atividade concluidas de Ana é: 10

# %%
#CARD TEMPO MEDIO POR ENTREGA
mediaconclusao = mentorada[mentorada['status_atual'] == 'concluida']['duracao_em_dias'].mean().round(1)
print(f'tempo médio(em dias) da conclusão é:{mediaconclusao}')
#card tempo medio por atividade em processo
mediandamento = mentorada[mentorada['status_atual'] == 'andamento']['duracao_em_dias'].mean().round(1)
print(f'tempo médio(em dias) do andamento é:{mediandamento}')
#card tempo medio que uma atividade fica pendente
mediapendente = mentorada[mentorada['status_atual'] == 'pendente']['duracao_em_dias'].mean().round(1)
print(f'tempo médio(em dias) da pendencia é:{mediapendente}')

TotalAtvAndamento = len(mentorada[mentorada['status_atual'] == 'andamento'])
fig, axes = plt.subplots(1, 2, figsize=(12, 2)) # 1 row, 2 columns

# Card 1: Concluídas
ax = axes[0]
ax.patch.set_facecolor('#f4f4f4')
fig.patch.set_facecolor('#f4f4f4')
for spine in ax.spines.values():
    spine.set_visible(False)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.text(0.5, 0.65, str(mediaconclusao), fontsize=30, fontweight='bold', ha='center', color='#333333', transform=ax.transAxes)
ax.text(0.5, 0.35, 'media de dias por atividades concluídas', fontsize=10, ha='center', color='#777777', transform=ax.transAxes)

# Card 2: Em Andamento
ax = axes[1]
ax.patch.set_facecolor('#f4f4f4')
fig.patch.set_facecolor('#f4f4f4')
for spine in ax.spines.values():
    spine.set_visible(False)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.text(0.5, 0.65, str(TotalAtvAndamento), fontsize=30, fontweight='bold', ha='center', color='#333333', transform=ax.transAxes)
ax.text(0.5, 0.35, 'atividades em andamento', fontsize=10, ha='center', color='#777777', transform=ax.transAxes)


plt.tight_layout()
plt.show()
# Out:
# tempo médio(em dias) da conclusão é:13.2
# tempo médio(em dias) do andamento é:7.0
# tempo médio(em dias) da pendencia é:14.0

# %% [markdown]
# ## PIZZA GRAFICO

# %%
#porcentagem de atividadesZ
status_andamento = mentorada['status_atual'].value_counts(normalize=True) * 100
#mentorada['status_atual'].value_counts(normalize=True) * 100 (para calcular ser ver o grafico)

# --- GRÁFICO 1: PIZZA (%STATUS DE TAREFAS DA MENTORA) ---

status_andamento = mentorada['status_atual'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(status_andamento, labels=status_andamento.index, autopct='%1.1f%%', colors=['#2f855a', '#e53e3e', '#dd6b20'])
plt.title('Distribuição Geral de Status das Atividades')
plt.savefig('grafico_status.png', transparent=True)

plt.show()
print(status_andamento)
# Out:
# status_atual
# concluida    10
# andamento     3
# pendente      3
# Name: count, dtype: int64

# %% [markdown]
# GRAFICO DINAMICO

# %%
# o grafico grande que é aO GRAFICO DE ANA Q MOSTRA AS ENTREGAS AO LONGO DAS SPRINGS.

#base ado nos dados gerais de todos os mentorados
concluidas_equipe = tabela[tabela['status_atual'] == 'concluida']
media_equipe = concluidas_equipe['duracao_em_dias'].mean()
teto_do_grafico = concluidas_equipe['duracao_em_dias'].max() + 2

# 2. pra cada atividade
mapa_de_cores = {
    'alta': '#E74C3C',    # Vermelho Alerta
    'Alta': '#E74C3C',
    'média': '#F39C12',   # Laranja/Amarelo Atenção
    'media': '#F39C12',
    'Média': '#F39C12',
    'baixa': '#2ECC71',   # Verde Tranquilo
    'Baixa': '#2ECC71'
}

# 3. definir grafico
def criar_grafico_evolucao(dataset_alvo, titulo_do_grafico):

    df_plot = dataset_alvo[dataset_alvo['status_atual'] == 'concluida'].copy()

#separar por sring
    df_plot['sprint_num'] = df_plot['titulo'].str.extract(r'Sprint (\d+)').astype(int)
    df_plot['nome_sprint'] = df_plot['titulo'].str.extract(r'(Sprint \d+)')
    df_plot = df_plot.sort_values('sprint_num')

    fig = px.scatter(
        df_plot,
        x='nome_sprint',
        y='duracao_em_dias',
        color='prioridade',
        color_discrete_map=mapa_de_cores,
        hover_data=['titulo', 'mentorado'],
        title=titulo_do_grafico,
        labels={'duracao_em_dias': 'Dias Gastos', 'nome_sprint': 'Sprint', 'prioridade': 'Dificuldade'}
    )

    fig.add_hline(
        y=media_equipe,
        line_dash="dash",
        line_color="gray",
        annotation_text=f"Média Geral ({media_equipe:.1f} dias)",
        annotation_position="bottom right"
    )

    # bolas do grafico
    fig.update_traces(marker=dict(size=14, opacity=0.8, line=dict(width=1, color='DarkSlateGrey')))
    fig.update_yaxes(range=[0, teto_do_grafico])

    return fig

# 3. GERANDO OS DOIS GRÁFICOS COM 1 LINHA DE CÓDIGO CADA

grafico_ana = criar_grafico_evolucao(mentorada, "Visão da Ana: Minha Evolução Individual")

# Exibindo as duas obras de arte

grafico_ana.show()

#oq esta acontecendo? : ele pega os dias gastos(duraçao_em_dias das atividades CONCLUIDAS) e coloca as sprint, ai podemos ver, de forma dinamica, as tarefas q foram concluidas, e as informações contidas

# %% [markdown]
# ##Tabela

# %%
#usar o historico de entregas de todos os mentorados para ter um parametro de atividade dos mentorados atravez das
historico_geral = tabela[tabela['status_atual'] == 'concluida']
media_por_prioridade = historico_geral.groupby('prioridade')['duracao_em_dias'].mean().round(1)

tabela_ativas_ana = mentorada[mentorada['status_atual'].isin(['andamento', 'pendente'])].copy()

# Injetamos a meta na tabela da Ana cruzando a prioridade
mentorada['meta_dias'] = mentorada['prioridade'].map(media_por_prioridade)

def sinalizar_status_real(linha): #verificação linha por linha do pandas para chegar nos resultados
    dias = linha['duracao_em_dias'] #mostra há quantos dias aquela atividade está rolando (desde que foi criada ou iniciada até a nossa data de corte).
    meta = linha['meta_dias_ana'] # é a media_por_prioridade que esta convertida em tabela

    if linha['status_atual'] == 'pendente':
        return '🔴 Crítico (Fila)' if dias > 10 else '⚪ Pendente Normal'

    elif linha['status_atual'] == 'andamento':
        if dias > (meta * 2):
            return '🔴 Crítico'
        elif dias > meta:
            return '🟡 Atrasado'
        else:
            # Adicionado para tarefas em 'andamento' mas 'Dentro do Prazo'
            return '🟢 Dentro do Prazo'
    else:
        # Adicionado para tarefas 'concluida' que não tinham retorno
        return '✔️ Entregue'

mentorada['Diagnostico'] = mentorada.apply(sinalizar_status_real, axis=1)
mentorada['dias_de_atraso'] = mentorada['duracao_em_dias'] - mentorada['meta_dias_ana']

atvd_ativa_ = mentorada[mentorada['status_atual'].isin(['andamento', 'pendente'])].copy()
tabela_completa_ana = atvd_ativa_[[
    'titulo', 'mentorado', 'prioridade', 'status_atual',
    'duracao_em_dias', 'meta_dias_ana', 'dias_de_atraso', 'Diagnostico'
]].sort_values(by='dias_de_atraso', ascending=False)




condicao_problema_ana = tabela_completa_ana['Diagnostico'].str.contains('🔴|🟡')
tabela_problemas_ana = tabela_completa_ana[condicao_problema_ana].drop(columns=['dias_de_atraso'])


print("=== TABELA DE visualização de atividades não entregues) ===")
display(tabela_problemas_ana)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'meta_dias_ana'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[144], line 29
#      25     else:
#      26         # Adicionado para tarefas 'concluida' que não tinham retorno
#      27         return '✔️ Entregue'
#      28
# ---> 29 mentorada['Diagnostico'] = mentorada.apply(sinalizar_status_real, axis=1)
#      30 mentorada['dias_de_atraso'] = mentorada['duracao_em_dias'] - mentorada['meta_dias_ana']
#      31
#      32 atvd_ativa_ = mentorada[mentorada['status_atual'].isin(['andamento', 'pendente'])].copy()
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\frame.py:12435, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12431                 engine_kwargs=engine_kwargs,
#   12432                 args=args,
#   12433                 kwargs=kwargs,
#   12434             )
# > 12435             return op.apply().__finalize__(self, method="apply")
#   12436         elif hasattr(engine, "__pandas_udf__"):
#   12437             if result_type is not None:
#   12438                 raise NotImplementedError(
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[144], line 12, in sinalizar_status_real(linha)
#      10 def sinalizar_status_real(linha): #verificação linha por linha do pandas para chegar nos resultados
#      11     dias = linha['duracao_em_dias'] #mostra há quantos dias aquela atividade está rolando (desde que foi criada ou iniciada até a nossa data de corte).
# ---> 12     meta = linha['meta_dias_ana'] # é a media_por_prioridade que esta convertida em tabela
#      13
#      14     if linha['status_atual'] == 'pendente':
#      15         return '🔴 Crítico (Fila)' if dias > 10 else '⚪ Pendente Normal'
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File c:\Users\lmm4\Documents\GitHub\Projeto-Final-Formacao-Full-Stack-\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'meta_dias_ana'

# %%
# 2. TABELA DE FLUXO NORMAL (Apenas 🟢 Prazo e ⚪ Fila Normal)
condicao_saudavel_ana = tabela_completa_ana['Diagnostico'].str.contains('🟢|⚪')
tabela_saudaveis_ana = tabela_completa_ana[condicao_saudavel_ana].drop(columns=['dias_de_atraso'])


display(tabela_saudaveis_ana)
# Out:
#                                     titulo    mentorado prioridade  \
# 66  Atualizar Scripts de Deploy - Sprint 9  Ana Ribeiro       alta
# 56   Otimizar Scripts de Deploy - Sprint 8  Ana Ribeiro       alta
# 49         Criar Pipeline CI/CD - Sprint 7  Ana Ribeiro       alta
#
#    status_atual  duracao_em_dias  meta_dias_ana        Diagnostico
# 66    andamento              5.0            9.9  🟢 Dentro do Prazo
# 56     pendente              4.0            9.9  ⚪ Pendente Normal
# 49    andamento              2.0            9.9  🟢 Dentro do Prazo

# %% [markdown]
# TABELA PARA VISUALIZAR OS SALDOS DE TODOS OS MENTORADOS E SUAS ATIVIDADES Q ESTAO FORA DA

# %%
#tabela geral
historico_geral = tabela[tabela['status_atual'] == 'concluida']
media_por_prioridade = historico_geral.groupby('prioridade')['duracao_em_dias'].mean().round(1)

tabela_ativas_ana = tabela[tabela['status_atual'].isin(['andamento', 'pendente'])].copy()

# Injetamos a meta na tabela tabela cruzando a prioridade
tabela['meta_dias'] = tabela['prioridade'].map(media_por_prioridade)

def sinalizar_status_real(linha):
    dias = linha['duracao_em_dias']
    meta = linha['meta_dias']

    if linha['status_atual'] == 'pendente':
        return '🔴 Crítico (Fila)' if dias > 10 else '⚪ Pendente Normal'

    elif linha['status_atual'] == 'andamento':
        if dias > (meta * 2):
            return '🔴 Crítico'
        elif dias > meta:
            return '🟡 Atrasado'
        else:
            # Adicionado para tarefas em 'andamento' mas 'Dentro do Prazo'
            return '🟢 Dentro do Prazo'
    else:
        # Adicionado para tarefas 'concluida' que não tinham retorno
        return '✔️ Entregue'

tabela['Diagnostico'] = tabela.apply(sinalizar_status_real, axis=1)
tabela['dias_de_atraso'] = tabela['duracao_em_dias'] - tabela['meta_dias']

# Pegamos apenas quem NÃO está concluído
tabela_ativas = tabela[tabela['status_atual'].isin(['andamento', 'pendente'])].copy()


tabela_completa = tabela_ativas[[
    'titulo', 'mentorado', 'prioridade', 'status_atual',
    'duracao_em_dias', 'meta_dias', 'dias_de_atraso', 'Diagnostico'
]].sort_values(by='dias_de_atraso', ascending=False)


#fazer o filtro para não mostrar nada que esteja ok, entregue ou no prazo
condicao_problema = tabela_completa['Diagnostico'].str.contains('🔴|🟡')
tabela_problemas = tabela_completa[condicao_problema].drop(columns=['dias_de_atraso'])


print("=== TABELA DE verificação de tividades não entregues")
display(tabela_problemas)
# Out:
# === TABELA DE verificação de tividades não entregues
#                                               titulo       mentorado  \
# 46           Testar Fluxo de Autenticação - Sprint 3  Felipe Andrade
# 5        Documentar Acessibilidade (WCAG) - Sprint 7  Henrique Alves
# 45               Testar Scripts de Deploy - Sprint 2   Diego Martins
# 0                 Otimizar Microsserviços - Sprint 8     Bruno Costa
# 8         Atualizar Acessibilidade (WCAG) - Sprint 1  Henrique Alves
# 57     Implementar Fluxo de Autenticação - Sprint 10  Gabriela Pinto
# 38               Testar Componentes React - Sprint 9   Diego Martins
# 23               Testar Scripts de Deploy - Sprint 2  Felipe Andrade
# 47                Analisar Pipeline CI/CD - Sprint 2  Felipe Andrade
# 36                Otimizar Pipeline CI/CD - Sprint 2     Ana Ribeiro
# 25            Atualizar Componentes React - Sprint 5   Eduarda Souza
# 72  Implementar Exportação de Relatórios - Sprint 10    Camila Lopes
# 60              Ajustar Componentes React - Sprint 2   Eduarda Souza
# 34              Implementar Tabelas no BD - Sprint 5     Ana Ribeiro
# 29             Criar Testes de Integração - Sprint 5   Diego Martins
# 37       Documentar Acessibilidade (WCAG) - Sprint 4  Henrique Alves
# 28                       Testar Dashboard - Sprint 6   Diego Martins
# 6                     Criar API de Login - Sprint 10     Bruno Costa
# 17          Implementar Scripts de Deploy - Sprint 1     Ana Ribeiro
# 24         Otimizar Fluxo de Autenticação - Sprint 8  Gabriela Pinto
# 40     Otimizar Exportação de Relatórios - Sprint 10    Camila Lopes
# 68            Criar Fluxo de Autenticação - Sprint 5  Gabriela Pinto
# 18               Criar Componentes React - Sprint 10   Eduarda Souza
#
#    prioridade status_atual  duracao_em_dias  meta_dias       Diagnostico
# 46       alta    andamento             24.0        9.9         🔴 Crítico
# 5       baixa    andamento             24.0       10.2         🔴 Crítico
# 45       alta    andamento             23.0        9.9         🔴 Crítico
# 0       media    andamento             24.0       11.4         🔴 Crítico
# 8       media    andamento             24.0       11.4         🔴 Crítico
# 57       alta    andamento             22.0        9.9         🔴 Crítico
# 38      media    andamento             23.0       11.4         🔴 Crítico
# 23       alta    andamento             20.0        9.9         🔴 Crítico
# 47      baixa     pendente             20.0       10.2  🔴 Crítico (Fila)
# 36      media     pendente             21.0       11.4  🔴 Crítico (Fila)
# 25      media    andamento             21.0       11.4        🟡 Atrasado
# 72      media     pendente             20.0       11.4  🔴 Crítico (Fila)
# 60       alta    andamento             18.0        9.9        🟡 Atrasado
# 34       alta     pendente             17.0        9.9  🔴 Crítico (Fila)
# 29       alta     pendente             17.0        9.9  🔴 Crítico (Fila)
# 37      baixa    andamento             16.0       10.2        🟡 Atrasado
# 28      media     pendente             16.0       11.4  🔴 Crítico (Fila)
# 6        alta     pendente             14.0        9.9  🔴 Crítico (Fila)
# 17       alta    andamento             14.0        9.9        🟡 Atrasado
# 24       alta    andamento             12.0        9.9        🟡 Atrasado
# 40      media     pendente             13.0       11.4  🔴 Crítico (Fila)
# 68       alta    andamento             10.0        9.9        🟡 Atrasado
# 18       alta    andamento             10.0        9.9        🟡 Atrasado

# %%
# 2. TABELA DE FLUXO NORMAL (Apenas 🟢 Prazo e ⚪ Fila Normal)
condicao_saudavel = tabela_completa['Diagnostico'].str.contains('🟢|⚪')
tabela_saudaveis = tabela_completa[condicao_saudavel].drop(columns=['dias_de_atraso'])

print("\n=== ✅ FLUXO NORMAL (TUDO SOB CONTROLE) ===")
display(tabela_saudaveis)
# Out:
# === ✅ FLUXO NORMAL (TUDO SOB CONTROLE) ===
#                                             titulo       mentorado prioridade  \
# 68          Criar Fluxo de Autenticação - Sprint 5  Gabriela Pinto       alta
# 18             Criar Componentes React - Sprint 10   Eduarda Souza       alta
# 63   Atualizar Exportação de Relatórios - Sprint 1    Camila Lopes      media
# 53    Implementar Fluxo de Autenticação - Sprint 1  Gabriela Pinto       alta
# 15  Documentar Exportação de Relatórios - Sprint 9    Camila Lopes      baixa
# 55              Analisar Microsserviços - Sprint 6   Diego Martins      baixa
# 66          Atualizar Scripts de Deploy - Sprint 9     Ana Ribeiro       alta
# 26                   Criar API de Login - Sprint 2     Bruno Costa       alta
# 27         Implementar Filtros de Busca - Sprint 3  Gabriela Pinto       alta
# 56           Otimizar Scripts de Deploy - Sprint 8     Ana Ribeiro       alta
# 42                Testar Pipeline CI/CD - Sprint 4   Diego Martins      media
# 49                 Criar Pipeline CI/CD - Sprint 7     Ana Ribeiro       alta
#
#    status_atual  duracao_em_dias  meta_dias        Diagnostico
# 68    andamento             10.0       10.3  🟢 Dentro do Prazo
# 18    andamento             10.0       10.3  🟢 Dentro do Prazo
# 63    andamento              9.0       11.4  🟢 Dentro do Prazo
# 53    andamento              6.0       10.3  🟢 Dentro do Prazo
# 15     pendente              5.0       10.2  ⚪ Pendente Normal
# 55     pendente              5.0       10.2  ⚪ Pendente Normal
# 66    andamento              5.0       10.3  🟢 Dentro do Prazo
# 26     pendente              5.0       10.3  ⚪ Pendente Normal
# 27     pendente              4.0       10.3  ⚪ Pendente Normal
# 56     pendente              4.0       10.3  ⚪ Pendente Normal
# 42     pendente              4.0       11.4  ⚪ Pendente Normal
# 49    andamento              2.0       10.3  🟢 Dentro do Prazo
